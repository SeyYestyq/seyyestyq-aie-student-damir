# %% [markdown]
# # Оценка системы и демонстрация
#
# Этот ноутбук содержит валидацию системы и сценарии демонстрации для Drop Forecaster.
#
# ## Проверки системы
# - Проверка работоспособности API
# - Полный E2E процесс с предсказаниями
# - Валидация производительности модели
# - Демо-предсказания

# %% [markdown]
# ## Рекомендуемый сценарий для защиты
# 1. Запустить API: `uvicorn src.api:app --port 8000`
# 2. Открыть `/docs` для Swagger UI
# 3. Отправить запрос на предсказание
# 4. Показать метрики модели и важность признаков
# 5. Запустить тесты: `pytest tests/ -v`

# %%
import sys
sys.path.insert(0, '..')

from src.model import get_model

# Загрузка модели
model = get_model()
print(f"Модель загружена: {model.is_loaded}")
print(f"Версия модели: {model.version}")
